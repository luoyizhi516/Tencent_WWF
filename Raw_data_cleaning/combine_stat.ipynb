# %%
import pandas as pd
import numpy as np
import os

# %%
def stat_count(dir):
    csv_list=os.listdir(dir)
    df_store=pd.DataFrame(columns=['Categories','Path','Frames'])
    for csv in csv_list:
        df=pd.read_csv(dir+csv)
        
        cat_list=df['Categories'].values
        
        for i,cate in enumerate(cat_list):
            if cate not in df_store['Categories'].values:
                df_store=df_store.append([{'Categories':cate}], ignore_index=True)
                index = df_store[df_store.Categories == cate].index.tolist()[0]

                df_store.loc[index,'Path']=[df.loc[i,'Path']]
                df_store.loc[index,'Frames']=df.loc[i,'Frames']
                
            else:
                index = df_store[df_store.Categories == cate].index.tolist()[0]

                df_store.loc[index,'Path']+=[df.loc[i,'Path']]
                df_store.loc[index,'Frames']+=df.loc[i,'Frames']
                
    df_store=df_store.sort_values(by="Frames" , ascending=False)
    df_store=df_store.reset_index().drop(['index'], axis=1)
    
    #df_store.to_csv('Stat.csv',index =False)
    return df_store

# %%
pd.set_option('display.max_rows', None)
stat_count('./csv/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-48ffd1c8250c> in <module>
#       1 pd.set_option('display.max_rows', None)
# ----> 2 stat_count('./csv/')
#
# <ipython-input-2-50f9033e333e> in stat_count(dir)
#       1 def stat_count(dir):
# ----> 2     csv_list=os.listdir(dir)
#       3     df_store=pd.DataFrame(columns=['Categories','Path','Frames'])
#       4     for csv in csv_list:
#       5         df=pd.read_csv(dir+csv)
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './csv/'

# %%
base='./csv//'
file_list=os.listdir(base)
for f in file_list:
    df=pd.read_csv(base+f)
    print(f)
    for i in df['Path'].values:
        print(i[:1],i[-1:])
# Out:
# 11_1.csv
# [ ]
# [ ]
# [ ]
# [ ]
# 34_02相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# 42_02原相机数据.csv
# [ ]
# [ ]
# 9_01原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_10_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_11_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_11_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_12_1相机(故障).csv
# [ ]
# [ ]
# HX_12_2相机(故障).csv
# [ ]
# [ ]
# HX_13_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_13_2相机.csv
# [ ]
# [ ]
# [ ]
# HX_14_1相机(故障).csv
# [ ]
# [ ]
# HX_14_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_15_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_15_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_16_1相机.csv
# [ ]
# [ ]
# [ ]
# HX_16_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_17_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_17_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_18_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_18_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_19_2相机(时间设置有误).csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_1_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_1_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_20_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_20_2相机.csv
# [ ]
# [ ]
# [ ]
# HX_21_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_21_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_22_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_22_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_23_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_23_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_2_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_2_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_3_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_3_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_4_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# HX_4_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_5_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_5_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_6_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_6_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_7_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_7_2相机.csv
# [ ]
# [ ]
# [ ]
# HX_8_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_8_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_9_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# HX_9_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_01_01分类.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_01_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_05_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_05_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_06_01.csv
# [ ]
# [ ]
# [ ]
# LCH_06_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_08_02.csv
# [ ]
# [ ]
# [ ]
# LCH_09_01_.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_09_02.csv
# [ ]
# [ ]
# [ ]
# LCH_11_02.csv
# [ ]
# LCH_12_01.csv
# [ ]
# [ ]
# LCH_13_01.csv
# [ ]
# [ ]
# [ ]
# LCH_13_02.csv
# [ ]
# [ ]
# LCH_15_01.csv
# [ ]
# [ ]
# LCH_15_02.csv
# [ ]
# [ ]
# LCH_16_05.csv
# [ ]
# LCH_16_06.csv
# [ ]
# LCH_18_01.csv
# [ ]
# [ ]
# LCH_20_01.csv
# [ ]
# [ ]
# LCH_22_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_22_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_23_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_23_02.csv
# [ ]
# [ ]
# LCH_24_01.csv
# [ ]
# [ ]
# LCH_24_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_25_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_25_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_26_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_27_02.csv
# [ ]
# [ ]
# [ ]
# LCH_2_01_.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_2_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_30_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_33_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_36_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_36_02.csv
# [ ]
# [ ]
# [ ]
# LCH_3_01.csv
# [ ]
# [ ]
# [ ]
# LCH_3_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_40_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_40_02.csv
# [ ]
# [ ]
# [ ]
# LCH_41_2.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# LCH_42_02.csv
# [ ]
# [ ]
# [ ]
# LCH_43_02.csv
# [ ]
# [ ]
# LCH_8_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_16_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_16_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# MC_17_1相机(时间设置有误).csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_17_2相机(故障).csv
# [ ]
# [ ]
# MC_18_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_18_2相机(无野生物种).csv
# [ ]
# [ ]
# [ ]
# [ ]
# MC_19_2相机(无动物）.csv
# [ ]
# [ ]
# MC_1_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_21_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_21_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_22_1相机(无动物）.csv
# [ ]
# [ ]
# MC_22_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_23_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_23_2相机(无动物）.csv
# [ ]
# [ ]
# MC_24_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_24_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_25_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# MC_26_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_27_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_27_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# MC_28_1相机.csv
# [ ]
# [ ]
# [ ]
# MC_2_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# MC_2_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_32_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_33_1相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_4_1相机(故障).csv
# [ ]
# [ ]
# MC_4_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# MC_9_2相机.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF-17-01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_01_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_01_02.csv
# [ ]
# [ ]
# [ ]
# QFGS_02_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_02_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_03_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_03_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_04_01.csv
# [ ]
# [ ]
# [ ]
# QFGS_04_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_06_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_07_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_07_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_09_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_10_01_202001.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_10_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_11_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_11_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_13_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_13_02.csv
# [ ]
# [ ]
# [ ]
# QFGS_14_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_14_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_AA01A.csv
# [ ]
# [ ]
# [ ]
# QFGS_AA02A.csv
# [ ]
# [ ]
# QFGS_AC06A.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFGS_AD04A.csv
# [ ]
# [ ]
# QFQQ_01_28.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_01_29.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_02_30.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_17_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_22_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_23_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_24_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_39_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QFQQ_41_01.csv
# [ ]
# QFQQ_42_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_06_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_20_41.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_21_33.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_27_40.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_37_03.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_37_04.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_54_38.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_XZL_01.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# QF_XZL_02.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_06_02相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20140423_16_01原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20191027_20_02相机数据.csv
# [ ]
# [ ]
# [ ]
# SDL_20191209_10_02原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20191221_08_02原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20200106_08_01原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20200124_41_01相机原数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20200309_43_01_原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20200309_45_02_原相机数据.csv
# [ ]
# [ ]
# [ ]
# SDL_20200327_09_02原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_20200328_17_02原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_24_01原相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# SDL_25_02相机数据.csv
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]

# %%
for i in new_df['Path'].values:
    for j in i:
        print(j[:1],j[-1:])
        #break
# Out:
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]
# [ ]

# %%
def sort_csv(csv_dir):
    df=pd.read_csv(csv_dir)
    df_store=pd.DataFrame(columns=['Categories','Path'])
    cat_list=df['Categories'].values 
    modify_class=['misssing','wufashibei','gongzuorengyuan','qitarenyuan','konpai']
    modified_class=['missing','wufashibie','gongzuorenyuan','gongzuorenyuan','kongpai']
    d
    drop_class=['wufashibie','kongpai','cuowu']
    for i,cate in enumerate(cat_list):
        
        if cate not in df_store['Categories'].values and cate not in modify_class:
            df_store=df_store.append([{'Categories':cate}], ignore_index=True)
            index = df_store[df_store.Categories == cate ].index.tolist()[0]
            df_store.loc[index,'Frames']=df.loc[i,'Frames']

            df_store.loc[index,'Path']=[df.loc[i,'Path']]

    for a,b in zip(modify_class,modified_class):
        index_a = df[df.Categories == a ].index.tolist()[0]
        index_b = df_store[df_store.Categories == b ].index.tolist()[0]
        df_store.loc[index_b,'Frames']+=df.loc[index_a,'Frames']

        df_store.loc[index_b,'Path']+=[df.loc[index_a,'Path']]
        
    index_p = df_store[df_store.Categories == 'gongzuorenyuan' ].index.tolist()[0]
    df_store.loc[index_p,'Categories']='person'
    df_store=df_store.sort_values(by="Frames" , ascending=False)
    

    df_store.reset_index()

    
    return df_store

# %%
def stat_count(dir):
    csv_list=os.listdir(dir)
    df_store=pd.DataFrame(columns=['Categories','Path','Frames'])
    modify_class=['misssing','wufashibei','gongzuorengyuan','qitarenyuan','konpai','gongzuorenyuan']
    modified_class=['missing','wufashibie','person','person','kongpai','person']
    drop_class=['cuowu','wufashibie','kongpai']
    for csv in csv_list:
        df=pd.read_csv(dir+csv)
        for a,b in zip(modify_class,modified_class):
            df.loc[df['Categories']==a,'Categories']=b
        
        cat_list=df['Categories'].values
        
        for i,cate in enumerate(cat_list):
            if cate not in df_store['Categories'].values and cate not in drop_class:
                df_store=df_store.append([{'Categories':cate}], ignore_index=True)
                index = df_store[df_store.Categories == cate].index.tolist()[0]

                df_store.loc[index,'Path']=[df.loc[i,'Path']]
                df_store.loc[index,'Frames']=df.loc[i,'Frames']
                
            elif cate in df_store['Categories'].values and cate not in drop_class:
                index = df_store[df_store.Categories == cate].index.tolist()[0]

                df_store.loc[index,'Path']+=[df.loc[i,'Path']]
                df_store.loc[index,'Frames']+=df.loc[i,'Frames']
                
                
    df_store=df_store.sort_values(by="Frames" , ascending=False)
    df_store=df_store.reset_index().drop(['index'], axis=1)
    
    return df_store

# %%
new_df=stat_count('./csv/')[:14]
display(new_df)
# Out:
#          Categories                                               Path  Frames
# 0           yanyang  [['E:\\隆畅河（分类删选）\\LCH_11_01分类\\LCH-11-01原数据\\L...  576555
# 1            maoniu  [['E:\\SDL原数据（分类删选）\\SDL_20200206_09_01\\SDL_2...  484428
# 2              malu  [['E:\\SDL原数据（分类删选）\\SDL_20200313_34_02\\SDL_2...  442930
# 3            person  [['E:\\隆畅河（分类删选）\\LCH_11_01分类\\LCH-11-01原数据\\L...  354976
# 4           lanmaji  [['E:\\哈溪/HX_11_2相机/100IMAGE\\HX_11_2_201912_0...  242963
# 5            xuebao  [['E:\\隆畅河（分类删选）\\LCH_11_01分类\\LCH-11-01原数据\\L...  200016
# 6              yang  [['E:\\哈溪/HX_15_2相机/100IMAGE\\HX_15_2_202001_0...  154760
# 7             chihu  [['E:\\SDL原数据（分类删选）\\SDL_20200206_09_01\\SDL_2...  140174
# 8         baichunlu  [['E:\\隆畅河（分类删选）\\LCH_01_01分类\\LCH01-01原数据\\LC...  135309
# 9             mashe  [['E:\\SDL原数据（分类删选）\\SDL_20200313_34_02\\SDL_2...   66567
# 10        gaoyuantu  [['E:\\SDL原数据（分类删选）\\SDL_20200206_09_01\\SDL_2...   61452
# 11               ma  [['E:\\哈溪/HX_2_1相机/100IMAGE\\HX_2_1_202003_032...   48831
# 12           zanghu  [['E:\\马场/MC_32_1相机/100MEDIA\\MC_32_1_202002_0...   44393
# 13  gaoyuanshanchun  [['E:\\哈溪/HX_21_1相机/100IMAGE\\HX_21_1_202003_0...   29818

# %%
new_df.loc[0,'Path'][0][1:-1].split(',')[-1].strip()[1:-1]
# coding:utf-8
# Out:
# 'E:\\\\隆畅河（分类删选）\\\\LCH_11_01分类\\\\LCH-11-01原数据\\\\LCH_11_01_201903_0552.JPG'

# %%
for i in range(2):
    save_name=str(i)+'.jpg'
    print(save_name)
    #cp 'E:\\\\隆畅河（分类删选）\\\\LCH_11_01分类\\\\LCH-11-01原数据\\\\LCH_11_01_201903_0013.JPG' save_name
# Out:
# 0.jpg
# 1.jpg

# %%
type(new_df['Path'][0])
# Out:
# list

# %%
from tqdm import tqdm

for cate,file_list in tqdm(zip(new_df['Categories'].values,new_df['Path'].values)):
    image_folder='D:/Dataset/'+cate+'/images/'
    video_folder='D:/Dataset/'+cate+'/videos/'
    if not os.path.exists(image_folder):
        os.makedirs(image_folder)
    if not os.path.exists(video_folder):
        os.makedirs(video_folder)
    count_image=0
    count_video=0
    for mini_list in tqdm(file_list):
        source_list=mini_list[1:-1].split(',')
        for s_item in source_list:
            source=s_item.strip()[1:-1]
            if source.lower().endswith('.jpg') or source.lower().endswith('.png') :
                count_image+=1
                target=image_folder+'%05d' % (count_image) +os.path.splitext(source)[1]
            elif source.lower().endswith('.mov') or source.lower().endswith('.avi') or source.lower().endswith('.mp4'):
                count_video+=1
                target=video_folder+'%05d' % (count_video) +os.path.splitext(source)[1]
            shutil.copyfile(source,target)
            #print(target)
# Out:
# 0it [00:00, ?it/s]
#   0%|                                                                                           | 0/66 [00:00<?, ?it/s]
#   2%|█▎                                                                                 | 1/66 [00:01<01:47,  1.66s/it]
#   3%|██▌                                                                                | 2/66 [00:02<00:59,  1.08it/s]
#   5%|███▊                                                                               | 3/66 [00:02<00:38,  1.65it/s]
#   6%|█████                                                                              | 4/66 [00:02<00:29,  2.08it/s]
#   8%|██████▎                                                                            | 5/66 [00:03<00:40,  1.52it/s]
#   9%|███████▌                                                                           | 6/66 [00:03<00:32,  1.85it/s]
#  11%|████████▊                                                                          | 7/66 [00:06<01:11,  1.20s/it]
#  12%|██████████                                                                         | 8/66 [00:06<00:53,  1.08it/s]
#  14%|███████████▎                                                                       | 9/66 [00:08<00:58,  1.02s/it]
#  17%|█████████████▋                                                                    | 11/66 [00:17<01:26,  1.58s/it]
# 0it [00:17, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-ea0cff1edf6c> in <module>
#      19                 count_video+=1
#      20                 target=video_folder+'%05d' % (count_video) +os.path.splitext(source)[1]
# ---> 21             shutil.copyfile(source,target)
#      22             #print(target)
#      23
#
# C:\ProgramData\Anaconda3\envs\yolo\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     277             # https://github.com/python/cpython/pull/7160#discussion_r195405230
#     278             elif _WINDOWS and file_size > 0:
# --> 279                 _copyfileobj_readinto(fsrc, fdst, min(file_size, COPY_BUFSIZE))
#     280                 return dst
#     281
#
# C:\ProgramData\Anaconda3\envs\yolo\lib\shutil.py in _copyfileobj_readinto(fsrc, fdst, length)
#     183     with memoryview(bytearray(length)) as mv:
#     184         while True:
# --> 185             n = fsrc_readinto(mv)
#     186             if not n:
#     187                 break
#
# KeyboardInterrupt:

# %%
import shutil
