# %%
# -*- coding: UTF-8 -*-
from math import e
import os

from numpy.lib.type_check import _imag_dispatcher
import pandas as pd
import shutil
import numpy as np
import cv2
import random
from tqdm import tqdm
import pyfastcopy
import json,sklearn
from sklearn.model_selection import train_test_split

# %%
pos_data_base='D:/WWF_Det/WWF_Data/Pos_Data/'
raw_data_base='D:/WWF_Det/WWF_Data/Raw_Data/'

annotation_base='D:/WWF_Det/WWF_Det/Raw_annoations/'

Final_data_base='D:/WWF_Det/WWF_Data/Final_Data/rest-vid-clean/'
try:
    os.makedirs(Final_data_base)
except:
    pass
data_dict={
        'img_path':[],
        'video_path':[],
        'cate':[],
        'modality':[],
        'label':[]
}
combine_data_list=['rest-part1','rest-part2']

# %%
for dataset in combine_data_list:
    source_vid_path_all=[]
    target_vid_path_all=[]
    valuableset_dir=pos_data_base+dataset+'/allset/visualizations/'
    source_base=raw_data_base+dataset+'/'
    source_base=source_base.replace('part','p')
    annotation_dir=annotation_base+dataset+'.csv'
    df=pd.read_csv(annotation_dir)
    pic_id_list=[i.replace('.jpg','',1) for i in os.listdir(valuableset_dir)]
    for pic_id in tqdm(pic_id_list):

            pic_df=df.loc[df['题目ID']== int(pic_id)]
            timu_str=pic_df['题目数据'].values[0]
            timu_data=json.loads(timu_str)
            video_path_list=timu_data['video_path'].split('/')
            vid_path=video_path_list[-3]+'/'+video_path_list[-2]+'/'+video_path_list[-1]
            source_vid_path_all.append(vid_path)
            target_vid_path_all.append(video_path_list[-3]+'-'+video_path_list[-1])
    source_vid_path_all=np.unique(np.array(source_vid_path_all)).tolist()
    target_vid_path_all=np.unique(np.array(target_vid_path_all)).tolist()

    for source_vid,target_vid in zip(source_vid_path_all,target_vid_path_all):
            shutil.copyfile(source_base+source_vid,Final_data_base+target_vid)
# Out:
# 100%|██████████| 3341/3341 [00:01<00:00, 2814.13it/s]
# 100%|██████████| 2677/2677 [00:00<00:00, 2873.89it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-2987fff7cbb8> in <module>
#      21
#      22     for source_vid,target_vid in zip(source_vid_path_all,target_vid_path_all):
# ---> 23             shutil.copyfile(source_base+source_vid,Final_data_base+target_vid)
#
# C:\ProgramData\Anaconda3\envs\yolo\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/WWF_Det/WWF_Data/Raw_Data/rest-p2/anfuxueji/videos/00001.AVI'

# %%
# Out:
# ['D:WWF_Det/WWF_Data/Raw_Data/rest-part1/anfuxueji/videos/00001.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/anfuxueji/videos/00002.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/anfuxueji/videos/00003.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00001.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00003.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00005.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00006.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00007.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00008.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00009.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00010.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00011.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00012.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00013.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00014.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00015.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00016.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00017.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00018.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00019.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00020.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00021.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00022.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00023.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00024.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00025.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00026.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00027.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00028.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00029.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00030.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00031.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00032.MP4', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00033.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00035.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00036.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00038.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00040.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00043.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00045.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00046.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00047.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00048.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00049.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00050.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00051.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/banchishanchun/videos/00052.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/danfuxueji/videos/00001.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/danfuxueji/videos/00003.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/danfuxueji/videos/00004.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/gaoyuanxuetu/videos/00006.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/gaoyuanxuetu/videos/00010.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/gaoyuanxuetu/videos/00013.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part1/gaoyuanxuetu/videos/00014.AVI', 'D:WWF_Det/WWF_Data/Raw_Data/rest-part ...
